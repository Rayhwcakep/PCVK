# %% [markdown]
# <a href="https://colab.research.google.com/github/Rayhwcakep/PCVK/blob/main/Latihan_Intergrasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import image
import matplotlib.pylab as plt

# %%
# membuat list untuk menyimpan url dari beberapa image
urls = ["https://uk.images.search.yahoo.com/search/images;_ylt=A2RTs3fabpZq4QIATR9NBQx.;_ylu=Y29sbwNhcC1zb3V0aGVhc3QtMQRwb3MDMQR2dGlkAwRzZWMDc3I-?fr=mcafee&p=gambar+kartun&imgurl=https%3A%2F%2Fimg.lovepik.com%2Fpng%2F20231105%2Fcute-kitten-cartoon-Kitten-cartoon-cartoon-animal-Cartoon-image_500066_wh1200.png",
"https://uk.images.search.yahoo.com/search/images;_ylt=A2RTs3fabpZq4QIAWx9NBQx.;_ylu=Y29sbwNhcC1zb3V0aGVhc3QtMQRwb3MDOAR2dGlkAwRzZWMDc3I-?fr=mcafee&p=gambar+kartun&imgurl=https%3A%2F%2Fpng.pngtree.com%2Fpng-clipart%2F20220614%2Foriginal%2Fpngtree-cartoon-funny-cat-sitting-on-white-background-png-image_8017160.png",
"https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2272/3910397744.py in <cell line: 0>()
#       6 # loop pada tiap url image, beberapa image dapat disimpan pada list
#       7 for url in urls:
# ----> 8   image = io.imread(url)                          #read image
#       9   image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
#      10   image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) #convert color to RGB
#
# NameError: name 'io' is not defined
